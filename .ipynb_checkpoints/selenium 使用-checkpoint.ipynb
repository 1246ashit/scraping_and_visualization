# %%
#下載
# !pip install selenium

# %%
#下載webdriver
#下載對應chrome版本的driver
#下載後會得到一個zip檔，解壓縮放在跟要使用的程式碼同個資料夾

# %%
from selenium import webdriver
url="https://www.youtube.com/watch?v=dQw4w9WgXcQ&ab_channel=RickAstley"
driver=webdriver.Chrome()
driver.get(url)
input("按下enter來關閉視窗")
driver.quit()
print("結束")
# Out:
# 按下enter來關閉視窗
# 結束
