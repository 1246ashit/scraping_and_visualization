# %%
#爬momo
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

url = 'https://www.momoshop.com.tw/category/MgrpCategory.jsp?m_code=3900100014'
driver = webdriver.Chrome()
driver.get(url)
ac=ActionChains(driver)

name=[]
price=[]
brand=[]


#擷取各品牌的商品
#共有22個廠牌
brandlist=["朵舒","舒潔","春風","TEMPO","柔情","得意",\
           "優活","優朵","綠荷","統潔","五月花","百吉牌",\
           "倍潔雅","唯潔雅","蒲公英","新新新","簡約組合",\
           "情人 / 雪柔","可麗舒/可立雅","極度純柔","日本大王"]
    
    
#爬朵舒的產品
for i in brandlist:
    try:
        driver.find_element_by_link_text(i).click()
        soup=BeautifulSoup(driver.page_source,"lxml")
        paper=soup.find("div",{'class':'prdListArea bt770class'})
      #紀錄資料
        for detail in soup.find_all("li",{"class":"eachGood"}):
            name.append(detail.find("h3",{"class":"prdName"}).text)#名子
            price.append(detail.find("span",{"class":"prdPrice"}).text)#價錢
            brand.append(i)#品牌
            print("-"*20)
        print(i,"完成")
    except:
        driver.find_element_by_link_text("更多").click()
        driver.find_element_by_link_text(i).click()
        soup=BeautifulSoup(driver.page_source,"lxml")
        paper=soup.find("div",{'class':'prdListArea bt770class'})
      #紀錄資料
        for detail in soup.find_all("li",{"class":"eachGood"}):
            name.append(detail.find("h3",{"class":"prdName"}).text)#名子
            price.append(detail.find("span",{"class":"prdPrice"}).text)#價錢
            brand.append(i)#品牌
            print("-"*20)
        print(i,"完成")
# Out:
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 朵舒 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 舒潔 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 春風 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# TEMPO 完成
# --------------------
# --------------------
# 柔情 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 得意 完成
# --------------------
# --------------------
# --------------------
# --------------------
# 優活 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 優朵 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 綠荷 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 統潔 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 五月花 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 百吉牌 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 倍潔雅 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 唯潔雅 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 蒲公英 完成
# --------------------
# --------------------
# --------------------
# --------------------
# 新新新 完成
# --------------------
# --------------------
# --------------------
# --------------------
# 簡約組合 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 情人 / 雪柔 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 可麗舒/可立雅 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 極度純柔 完成
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 日本大王 完成

# %%
#資料整理成excel 
import pandas as pd

toilet_paper= pd.DataFrame({'品牌':brand,
                    '品項名子':name,
                    '價格':price
                        
                      })
print(toilet_paper)
toilet_paper.to_csv("toilet_paper.csv")
# Out:
#        品牌                                      品項名子    價格
# 0      朵舒           【朵舒】超厚柔棉仔紙抽取式衛生紙(150抽x12包x6袋/箱)  $679
# 1      朵舒              【朵舒】舒適柔抽取式衛生紙(150抽x10包x8袋/箱)  $829
# 2      朵舒            【朵舒】極細柔抽取式花紋衛生紙(200抽x12包x4袋/箱)  $679
# 3      朵舒          【朵舒】朵舒極緻舒適3層抽取式花紋衛生紙(100抽x48包/箱)  $599
# 4      朵舒           【朵舒】超厚柔棉仔紙抽取式衛生紙(100抽x12包x8袋/箱)  $719
# ..    ...                                       ...   ...
# 326  日本大王          【日本大王】elleair 超強韌廚房紙巾6包組(50抽/2捲)  $595
# 327  日本大王             【日本大王】elleair 超強韌廚房紙巾(50抽/2捲)  $119
# 328  日本大王          【日本大王】elleair 超強韌廚房紙巾3包組(50抽/2捲)  $297
# 329  日本大王    【日本大王】elleair 芯香花苑三層捲筒衛生紙_洋甘菊3包組(4捲/包)  $447
# 330  日本大王  【日本大王】elleair奢侈保濕柔霜面紙攜帶包衛生紙14抽x4包入(10袋組)  $690
#
# [331 rows x 3 columns]

# %%
import seaborn as sns
